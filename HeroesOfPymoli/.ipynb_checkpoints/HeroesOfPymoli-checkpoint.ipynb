# %%
# import and set alias for pandas
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\freed\\class_folder\\Pandas-Challenge\\HeroesOfPymoli'

# %%
# read in purchase_data.csv file

data_file = "../../gt-virt-data-pt-12-2021-u-c/04-Pandas/Homework/HeroesOfPymoli/Resources/purchase_data.csv"

# %%
heroes_data = pd.read_csv(data_file)

# %%
heroes_data.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
heroes_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %%
unique_cnt = heroes_data["SN"].nunique()
unique_cnt
# Out:
# 576

# %%
# create number as dataframe to print as requested with index

# %%
# create purchasing analysis stats: # unique items, avg price, # purchases and total revenue
heroes_data["Item Name"].nunique()
heroes_data["Price"].mean()
heroes_data["Purchase ID"].count()
heroes_data["Price"].sum()
# Out:
# 2379.77

# %%
# create a unique data set of customers
unique_cust = heroes_data.drop_duplicates(subset = "SN", inplace = False)
unique_cust
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male       92
# 775          775     Aethedru70   21  Female       60
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 773              Pursuit, Cudgel of Necromancy   1.02
# 774                               Final Critic   4.19
# 775                                       Wolf   3.54
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
#
# [576 rows x 7 columns]

# %%
gender_df = pd.DataFrame(unique_cust["Gender"].value_counts())
gender_df["Percent"] = gender_df["Gender"]/gender_df["Gender"].sum()
gender_df
# Out:
#                        Gender   Percent
# Male                      484  0.840278
# Female                     81  0.140625
# Other / Non-Disclosed      11  0.019097

# %%
gender_summary = heroes_data[["Gender", "SN", "Price"]]

# %%
#test = heroes_data[["Gender", "SN", "Price"]].groupby(["Gender"]).agg(['sum', 'count','nunique'])
#test_new.columns = ['_'.join(col) if type(col) is tuple else col for col in test.columns.values]
#test = test.rename(columns={('Price',     'sum'): "new name"})
test.rename(columns = {"SN":"sum", "SN": "count", "SN": "nunique", "Price":"sum", "Price": "count", "Price": "nunique"})
test
# Out:
#                                                                       SN  \
#                                                                      sum
# Gender
# Female                 Lisassa64Reunasu60Reulae52Assosia88Phaelap26Ch...
# Male                   Lisim78Lisovynya38Ithergue48Chamassasya86Iskos...
# Other / Non-Disclosed  Chanosian48Siarithria38Haerithp41Sundim98Jiski...
#
#                                        Price
#                       count nunique      sum count nunique
# Gender
# Female                  113      81   361.94   113      79
# Male                    652     484  1967.64   652     144
# Other / Non-Disclosed    15      11    50.19    15      12

# %%
test.columns
# Out:
# MultiIndex([(   'SN',     'sum'),
#             (   'SN',   'count'),
#             (   'SN', 'nunique'),
#             ('Price',     'sum'),
#             ('Price',   'count'),
#             ('Price', 'nunique')],
#            )

# %%
new_df_test = gender_summary.groupby(["Gender"]).agg(['sum', 'count','nunique'])
new_df_test["avgpur"] = new_df_test[('Price',     'sum')]/new_df_test[('SN', 'count')]
new_df_test["avgpurcust"] = new_df_test[('Price',     'sum')]/new_df_test[('SN', 'nunique')]
new_df_test
# Out:
#                                                                       SN  \
#                                                                      sum
# Gender
# Female                 Lisassa64Reunasu60Reulae52Assosia88Phaelap26Ch...
# Male                   Lisim78Lisovynya38Ithergue48Chamassasya86Iskos...
# Other / Non-Disclosed  Chanosian48Siarithria38Haerithp41Sundim98Jiski...
#
#                                        Price                  avgpur  \
#                       count nunique      sum count nunique
# Gender
# Female                  113      81   361.94   113      79  3.203009
# Male                    652     484  1967.64   652     144  3.017853
# Other / Non-Disclosed    15      11    50.19    15      12  3.346000
#
#                       avgpurcust
#
# Gender
# Female                  4.468395
# Male                    4.065372
# Other / Non-Disclosed   4.562727

# %%
new_df_test.columns
# Out:
# MultiIndex([(        'SN',     'sum'),
#             (        'SN',   'count'),
#             (        'SN', 'nunique'),
#             (     'Price',     'sum'),
#             (     'Price',   'count'),
#             (     'Price', 'nunique'),
#             (    'avgpur',        ''),
#             ('avgpurcust',        '')],
#            )

# %%
new_df_test
# Out:
#                                                                       SN  \
#                                                                      sum
# Gender
# Female                 Lisassa64Reunasu60Reulae52Assosia88Phaelap26Ch...
# Male                   Lisim78Lisovynya38Ithergue48Chamassasya86Iskos...
# Other / Non-Disclosed  Chanosian48Siarithria38Haerithp41Sundim98Jiski...
#
#                                        Price                  avgpur  \
#                       count nunique      sum count nunique
# Gender
# Female                  113      81   361.94   113      79  3.203009
# Male                    652     484  1967.64   652     144  3.017853
# Other / Non-Disclosed    15      11    50.19    15      12  3.346000
#
#                       avgpurcust
#
# Gender
# Female                  4.468395
# Male                    4.065372
# Other / Non-Disclosed   4.562727

# %%
keep_df = new_df_test[(        'SN',   'count'), (    'avgpur',        ''), (     'Price',     'sum'), ('avgpurcust',        '')]
keep_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-e84bb09c38d1> in <module>
# ----> 1 keep_df = new_df_test[(        'SN',   'count'), (    'avgpur',        ''), (     'Price',     'sum'), ('avgpurcust',        '')]
#       2 keep_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3455         if is_single_key:
#    3456             if self.columns.nlevels > 1:
# -> 3457                 return self._getitem_multilevel(key)
#    3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_multilevel(self, key)
#    3506     def _getitem_multilevel(self, key):
#    3507         # self.columns is a MultiIndex
# -> 3508         loc = self.columns.get_loc(key)
#    3509         if isinstance(loc, (slice, np.ndarray)):
#    3510             new_columns = self.columns[loc]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2925         keylen = len(key)
#    2926         if self.nlevels < keylen:
# -> 2927             raise KeyError(
#    2928                 f"Key length ({keylen}) exceeds index depth ({self.nlevels})"
#    2929             )
#
# KeyError: 'Key length (4) exceeds index depth (2)'
